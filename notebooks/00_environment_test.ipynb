# %%
print("Data Engineering Project Started 🚀")

# %%
data = [
    ("Laptop", 75000),
    ("Phone", 45000),
    ("Monitor", 25000)
]

df = spark.createDataFrame(
    data,
    ["product_name", "sales"]
)

display(df)

# %%
df.write \
    .format("delta") \
    .mode("overwrite") \
    .saveAsTable("project_setup_test")
