# %%
s3_url="s3://rahul-company-merger-data-lake/company_a/raw/products/products_2025_01.csv"

df_products=(
    spark.read
    .option("header","true")
    .option("inferSchema","true")
    .csv(s3_url)
)

display(df_products)

# %%
df_products.printSchema()
